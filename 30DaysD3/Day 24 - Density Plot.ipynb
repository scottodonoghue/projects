# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load in the drivers data and the the data on race results. We will only really use the drivers data to check the driver ID for the drivers of interest (in this case, just Lewis Hamilton).

# %%
drivers = pd.read_csv('data/drivers.csv')
drivers['name'] = drivers.forename + " " + drivers.surname
drivers = drivers[['driverId','number', 'code', 'name']]
drivers.head()
# Out:
#    driverId number code               name
# 0         1     44  HAM     Lewis Hamilton
# 1         2     \N  HEI      Nick Heidfeld
# 2         3      6  ROS       Nico Rosberg
# 3         4     14  ALO    Fernando Alonso
# 4         5     \N  KOV  Heikki Kovalainen

# %%
results = pd.read_csv('data/results.csv')
results.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# ...

# %% [markdown]
# Get Lewis Hamilton's results:

# %%
hamilton = results[results.driverId == 1]
driver.head()
# Out:
#     resultId  raceId  driverId  constructorId number  grid position  \
# 0          1      18         1              1     22     1        1
# 26        27      19         1              1     22     9        5
# 56        57      20         1              1     22     3       13
# 68        69      21         1              1     22     5        3
# 89        90      22         1              1     22     3        2
#
#    positionText  positionOrder  points  laps         time milliseconds  \
# 0             1              1    10.0    58  1:34:50.616      5690616
# 26            5              5     4.0    56      +46.548      5525103
# 56           13             13     0.0    56           \N           \N
# 68            3              3     6.0    66       +4.187      5903238
# 89            2              2     8.0    58       +3.779      5213230
#
#    fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0          39    2       1:27.452         218.300         1
# ...

# %% [markdown]
# Quick test of hwo the final plot will look:

# %%
sns.displot(hamilton, x="positionOrder", kind="kde")

# %% [markdown]
# We will only need the positionOrder column, so let's separate that out from the rest of the data:

# %%
data = driver[['positionOrder']]
data.head()
# Out:
#     positionOrder
# 0               1
# 26              5
# 56             13
# 68              3
# 89              2

# %%
data.to_csv('C://Users/Scott/Documents/Projects/Vue/website3/public/hamilton_finish_positions.csv')
data.to_csv('data/hamilton_finish_positions.csv')

# %%
data.mean()
# Out:
# positionOrder    4.796992
# dtype: float64
